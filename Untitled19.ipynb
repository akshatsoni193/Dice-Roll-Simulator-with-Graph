# %% [markdown]
# <a href="https://colab.research.google.com/github/akshatsoni193/Dice-Roll-Simulator-with-Graph/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
a=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=4c1dbb0eddf17250fbd43bb68992ef04')

# %%
a.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/pNjh59JSxChQktamG3LMp9ZoQzp.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 28.7871,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.712,
#    'vote_count': 28849},
#   {'adult': False,
#    'backdrop_path': '/htuuuEwAvDVECMpb0ltLLyZyDDt.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
df = pd.DataFrame(a.json()['results']).head(2)[['id','title','release_date','vote_average']]

# %%
df = pd.DataFrame()

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
  a=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=4c1dbb0eddf17250fbd43bb68992ef04'.format(i))
  temp_df = pd.DataFrame(a.json()['results']).head(2)[['id','title','release_date','vote_average']]
df = df.append(temp_df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2869605671.py in <cell line: 0>()
#       2   a=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=4c1dbb0eddf17250fbd43bb68992ef04'.format(i))
#       3   temp_df = pd.DataFrame(a.json()['results']).head(2)[['id','title','release_date','vote_average']]
# ----> 4 df = df.append(temp_df,ignore_index=True)
#       5
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'append'
